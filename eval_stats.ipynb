# %%
import pandas as pd

# %%
data = pd.read_csv('output.csv', header=None)
data
# Out:
#       0               1   2   \
# 0      0  2834146886.mp4  TN
# 1      1  3441428429.mp4  TN
# 2      2  6356067859.mp4  TN
# 3      3  5735711594.mp4  TC
# 4      4  5296635780.mp4  TN
# ..   ...             ...  ..
# 345  438  3375218204.mp4  TN
# 346  439  4036955771.mp4  TC
# 347  440  4412508597.mp4  TC
# 348  441  5237219621.mp4  TN
# 349  442  4272084125.mp4  TN
#
#                                                     3   4   \
# 0    what does the white dog do after going to the ...   2
# 1    what does the female skater do after the male ...   1
# 2    what does the girl in white do after bending d...   1
# 3    how did the white dog respond to the brown dog...   1
# 4    what does the man do after the lady appear to ...   3
# ..                                                 ...  ..
# 345  what is the response of the man after the girl...   0
# 346  what does the man on the extreme right play as...   3
# 347  what does the lady in blue do as the boy was m...   2
# ...

# %%
match = data.iloc[:, 4] == data.iloc[:, 10]
match.mean()
# Out:
# 0.5171428571428571

# %%
wrong = data[~match]
wrong
# Out:
#       0               1   2   \
# 0      0  2834146886.mp4  TN
# 3      3  5735711594.mp4  TC
# 4      4  5296635780.mp4  TN
# 6      7  6018490041.mp4  TN
# 7     12  4094488636.mp4  TN
# ..   ...             ...  ..
# 335  427  6898821807.mp4  TN
# 338  431  4219909195.mp4  TN
# 342  435  6291413193.mp4  TC
# 345  438  3375218204.mp4  TN
# 347  440  4412508597.mp4  TC
#
#                                                     3   4   \
# 0    what does the white dog do after going to the ...   2
# 3    how did the white dog respond to the brown dog...   1
# 4    what does the man do after the lady appear to ...   3
# 6    what does the man in white do after moving for...   2
# 7    what does the brown dog do after stepping over...   1
# ..                                                 ...  ..
# 335  what does the baby do after grabbing the boy s...   3
# 338  what did the girl do after the man pat the pil...   0
# 342  how is the lady in white positioned in the water?   0
# ...
